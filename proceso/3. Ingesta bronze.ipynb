-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
dbutils.widgets.text("container", "raw")
dbutils.widgets.text("catalogo", "catalog_gamd")
dbutils.widgets.text("esquema", "bronze")
dbutils.widgets.text("storageName", "adlsgamd26")

# constantes para scope de nuestro datalake
scope = "accessScopeforDL"
key = "storageAccessKey"

-- %%
%python
container = dbutils.widgets.get("container")
catalogo = dbutils.widgets.get("catalogo")
esquema = dbutils.widgets.get("esquema")
storageName = dbutils.widgets.get("storageName")

-- %%
%python
spark.conf.set(f"fs.azure,account.key.{storageName}.dfs.core.windows.net", dbutils.secrets.get(scope = f"{scope}", key = f"{key}"))

-- %% [markdown]
-- ###INGESTA BRONZE

-- %% [markdown]
-- #### Origen de datos aisles

-- %%
%python

# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/aisles.csv"

# Leer el archivo CSV y guardar en dataframe
df_aisles = spark.read.format("csv")\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.load(ruta)

-- %%
%python
df_aisles.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.aisles")

-- %% [markdown]
-- #### Origen de datos order_products_pior

-- %%
%python
# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/order_products__prior.csv"

# Leer el archivo CSV y guardar en dataframe
df_order_products = spark.read\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.csv(ruta)

-- %%
%python
df_order_products.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.order_products_prior")

-- %% [markdown]
-- #### Origen de datos order_products_train

-- %%
%python
# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/order_products__train.csv"

# Leer el archivo CSV y guardar en dataframe
df_order_products_train =spark.read\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.csv(ruta)

-- %%
%python
df_order_products_train.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.order_products_train")

-- %% [markdown]
-- #### Origen de datos orders

-- %%
%python

# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/orders.csv"

# Leer el archivo CSV y guardar en dataframe
df_orders = spark.read\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.csv(ruta)

-- %%
%python
df_orders.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.orders")

-- %% [markdown]
-- #### Origen de datos sample submission

-- %%
%python
# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/sample_submission.csv"

# Leer el archivo CSV y guardar en dataframe
df_sample_submission = spark.read\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.csv(ruta)

-- %%
%python
df_sample_submission.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.sample_submission")

-- %% [markdown]
-- #### Origen de datos products

-- %%
%python
# ruta de fuente CSV
ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/products.csv"

# Leer el archivo CSV y guardar en dataframe
df_products = spark.read\
.option('header', True)\
.option('sep', ";")\
.option("inferSchema", "true")\
.csv(ruta)

-- %%
%python
df_products.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable(f"{catalogo}.{esquema}.products")

-- %% [markdown]
-- ### Origen de datos Azure SQL DB:
--
-- Tablas: deparments

-- %%
%python
#import getpass
# constantes para scope de nuestro datalake
scopesql = "scopeforSQL"
keysql = "passjdbcSQL"

-- %%
%python
jdbcHostname = "sqlgamd.database.windows.net"
jdbcDatabase = "sqlstore"
jdbcPort = 1433
jdbcUsername = "sa_gamd"
jdbcPassword = dbutils.secrets.get(scope = f"{scopesql}", key = f"{keysql}")

-- %%
%python
# URL JDBC
jdbcUrl = f"jdbc:sqlserver://{jdbcHostname}:{jdbcPort};database={jdbcDatabase};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"

-- %% [markdown]
-- ### Table Deparments

-- %%
%python
tableName = "departments"

df_departments = spark.read.format("jdbc") \
    .option("url", jdbcUrl) \
    .option("dbtable", tableName) \
    .option("user", jdbcUsername) \
    .option("password", jdbcPassword) \
    .load()

-- %%
%python
df_departments.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.departments")
