-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
#dbutils.widgets.text("nameContainer","metastore")
dbutils.widgets.text("nameStorage","adlsgamd26")
dbutils.widgets.text("catalogo","catalog_gamd")

-- %%
%python

#nameContainer = dbutils.widgets.get("nameContainer")
nameStorage = dbutils.widgets.get("nameStorage")
catalogo = dbutils.widgets.get("catalogo")

#ruta = f"abfss://{nameContainer}@{nameStorage}.dfs.core.windows.net"

-- %% [markdown]
-- ### Eliminacion tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.bronze.aisles;
DROP TABLE IF EXISTS ${catalogo}.bronze.departments;
DROP TABLE IF EXISTS ${catalogo}.bronze.order_products_pior;
DROP TABLE IF EXISTS ${catalogo}.bronze.order_products_train;
DROP TABLE IF EXISTS ${catalogo}.bronze.orders;
DROP TABLE IF EXISTS ${catalogo}.bronze.products;
DROP TABLE IF EXISTS ${catalogo}.bronze.sample_submission;

-- %%
%python
## REMOVE DATA (Bronze)

dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/aisles/",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/departments",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/order_products_prior",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/order_products_train",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/orders",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/products",True)
dbutils.fs.rm(f"abfss://bronze@{nameStorage}.dfs.core.windows.net/sample_submission",True)

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.silver.order_products;
DROP TABLE IF EXISTS ${catalogo}.silver.orders;
DROP TABLE IF EXISTS ${catalogo}.silver.eval_set;

-- %%
%python
# REMOVE DATA (Silver)
#dbutils.fs.rm(f"{ruta}/tablas/order_products", True)
#dbutils.fs.rm(f"{ruta}/tablas/orders", True)
#dbutils.fs.rm(f"{ruta}/tablas/eval_set", True)

dbutils.fs.rm(f"abfss://silver@{nameStorage}.dfs.core.windows.net/",True)

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.golden.kpis_users;
DROP TABLE IF EXISTS ${catalogo}.golden.kpis_products_ordered;
DROP TABLE IF EXISTS ${catalogo}.golden.kpis_eval_set;

-- %%
%python
# REMOVE DATA (Golden)
#dbutils.fs.rm(f"{ruta}/tablas/kpis_products_ordered", True)
#dbutils.fs.rm(f"{ruta}/tablas/kpis_deparments", True)

dbutils.fs.rm(f"abfss://golden@{nameStorage}.dfs.core.windows.net/",True)
